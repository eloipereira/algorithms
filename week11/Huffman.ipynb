# %%
import heapq as h

# %%
fh = open('huffman.txt','r')

# %%
n = int(fh.readline())

# %%
weights = list(map(int,fh.readlines()))

# %%
alphabet = []

# %%
for i in range(n):
    h.heappush(alphabet,(weights[i],str(i)))

# %%
V = {}

# %%
class BinaryTree:
    
    def __init__(self, left = None, right = None, value = None):
        self.value = value
        self.left = BinaryTree(None, None, left) if left else None
        self.right = BinaryTree(None, None, right) if right else None
        V[self.value] = self

    def getLength(self, fn):
        if not (self.left and self.right):
              return 0

        leftLength = self.left.getLength(fn) if self.left else 0
        rightLength = self.right.getLength(fn) if self.right else 0

        return 1 + fn(leftLength, rightLength)

# %%
def huffman(alphabet):
    assert(len(alphabet) > 1)
    
    # Base case
    if len(alphabet) == 2:
        return BinaryTree(alphabet[0][1],alphabet[1][1])
    
    # Recursive step
    (wa, a) = h.heappop(alphabet)
    (wb, b) = h.heappop(alphabet)
    
    ab = a + '_' + b
    h.heappush(alphabet,(wa+wb,ab))
    
    tree = huffman(alphabet)
    
    V[ab].__dict__.update(BinaryTree(a, b))
    
    return tree

# %%
tree = huffman(alphabet)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-152-6ee44a9a8fab> in <module>()
# ----> 1 tree = huffman(alphabet)
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
# ...
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      13     h.heappush(alphabet,(wa+wb,ab))
#      14
# ---> 15     tree = huffman(alphabet)
#      16
#      17     V[ab].__dict__.update(BinaryTree(a, b))
#
# <ipython-input-151-66c7d45179bb> in huffman(alphabet)
#      15     tree = huffman(alphabet)
#      16
# ---> 17     V[ab].__dict__.update(BinaryTree(a, b))
#      18
#      19     return tree
#
# TypeError: 'BinaryTree' object is not iterable

# %%
print(tree.getLength(min)) 
print(tree.getLength(max))
# Out:
# 9
# 19
